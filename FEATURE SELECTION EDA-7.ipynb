# %% [markdown]
# # FEATURE SELECTION TECHNIQUES

# %%
import pandas as pd 
df=pd.read_csv("train.csv")

# %%
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
from sklearn.preprocessing import StandardScaler
df_sc=StandardScaler()
df_sc2=df_sc.fit_transform(df)

# %%
a2=pd.DataFrame(df_sc2,columns=df.columns)

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.hist(a2['battery_power'],bins=30)
# Out:
# (array([73., 75., 75., 63., 73., 63., 76., 67., 67., 65., 60., 74., 59.,
#         77., 54., 63., 70., 52., 71., 61., 61., 80., 57., 64., 70., 58.,
#         69., 67., 59., 77.]),
#  array([-1.67881744, -1.5652298 , -1.45164215, -1.3380545 , -1.22446686,
#         -1.11087921, -0.99729157, -0.88370392, -0.77011627, -0.65652863,
#         -0.54294098, -0.42935334, -0.31576569, -0.20217804, -0.0885904 ,
#          0.02499725,  0.1385849 ,  0.25217254,  0.36576019,  0.47934783,
#          0.59293548,  0.70652313,  0.82011077,  0.93369842,  1.04728606,
#          1.16087371,  1.27446136,  1.388049  ,  1.50163665,  1.61522429,
#          1.72881194]),
#  <BarContainer object of 30 artists>)

# %%
import numpy as np
a2['battery_power1']=np.log1p(a2['battery_power'])
# Out:
# C:\Users\DELL\anaconda\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: invalid value encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
plt.hist(a2['battery_power1'],bins=80)
# Out:
# (array([  1.,   0.,   0.,   0.,   0.,   2.,   0.,   0.,   0.,   2.,   0.,
#           0.,   1.,   0.,   3.,   0.,   0.,   0.,   2.,   4.,   1.,   0.,
#           0.,   1.,   1.,   1.,   1.,   2.,   3.,   2.,   2.,   4.,   4.,
#           6.,   1.,   8.,   5.,   2.,   6.,   6.,   4.,   7.,   7.,   6.,
#          11.,   6.,  13.,   3.,  10.,   8.,  18.,  18.,  10.,   8.,  16.,
#          20.,  14.,  23.,  22.,  18.,  27.,  39.,  30.,  26.,  37.,  49.,
#          40.,  40.,  55.,  49.,  59.,  52.,  67.,  76.,  98.,  83.,  95.,
#          98., 116., 129.]),
#  array([-5.50307653, -5.42173975, -5.34040296, -5.25906617, -5.17772939,
#         -5.0963926 , -5.01505582, -4.93371903, -4.85238225, -4.77104546,
#         -4.68970867, -4.60837189, -4.5270351 , -4.44569832, -4.36436153,
#         -4.28302475, -4.20168796, -4.12035117, -4.03901439, -3.9576776 ,
#         -3.87634082, -3.79500403, -3.71366724, -3.63233046, -3.55099367,
# ...

# %%
df1=pd.read_csv("train.csv")

# %%
df1
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %% [markdown]
# # UNI-VARIATE SELECTION

# %%
x=df1.iloc[:,:-1]
y=df1['price_range']

# %%
x.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2   2         20       756  2549     9     7         19
# 1        136        3   6        905      1988  2631    17     3          7
# 2        145        5   6       1263      1716  2603    11     2          9
# 3        131        6   9       1216      1786  2769    16     8         11
# 4        141        2  14       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi
# ...

# %%
y.head()
# Out:
# 0    1
# 1    2
# 2    2
# 3    2
# 4    1
# Name: price_range, dtype: int64

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
# apply kbest algorithm
ordered_rank_features=SelectKBest(score_func=chi2,k=20)
ordered_feature=ordered_rank_features.fit(x,y)
df_scores=pd.DataFrame(ordered_feature.scores_,columns=['Score'])

# %%
dfcolumns=pd.DataFrame(x.columns)

# %%
df3=pd.concat([dfcolumns,df_scores],axis=1)

# %%
df3.columns=['features','score']

# %%
df3.head()
# Out:
#         features         score
# 0  battery_power  14129.866576
# 1           blue      0.723232
# 2    clock_speed      0.648366
# 3       dual_sim      0.631011
# 4             fc     10.135166

# %%
df3.nlargest(10,'score')
# Out:
#          features          score
# 13            ram  931267.519053
# 11      px_height   17363.569536
# 0   battery_power   14129.866576
# 12       px_width    9810.586750
# 8       mobile_wt      95.972863
# 6      int_memory      89.839124
# 15           sc_w      16.480319
# 16      talk_time      13.236400
# 4              fc      10.135166
# 14           sc_h       9.614878

# %% [markdown]
# # feature importance
# this technique gives you a score for each feature of your data , the higher the score more relavent it is

# %%
from sklearn.ensemble import ExtraTreesClassifier 
import matplotlib.pyplot as plt
model=ExtraTreesClassifier()

# %%
model.fit(x,y)
# Out:
# ExtraTreesClassifier()

# %%
print(model.feature_importances_)
# Out:
# [0.06134279 0.01958387 0.03313528 0.01851936 0.03221495 0.01769385
#  0.03643905 0.03487794 0.03743659 0.03344037 0.03364029 0.04663912
#  0.04820075 0.38664362 0.03529999 0.03499079 0.03622486 0.01445608
#  0.01908013 0.02014031]

# %%
ranked_feature=pd.Series(model.feature_importances_,index=x.columns)
ranked_feature.nlargest(10).plot(kind='barh')
plt.show()

# %% [markdown]
# # correlation

# %%
import seaborn as sns 
corr=df.iloc[:,:-1].corr()

# %%
corr.head()
# Out:
#                battery_power      blue  clock_speed  dual_sim        fc  \
# battery_power       1.000000  0.011252     0.011482 -0.041847  0.033334
# blue                0.011252  1.000000     0.021419  0.035198  0.003593
# clock_speed         0.011482  0.021419     1.000000 -0.001315 -0.000434
# dual_sim           -0.041847  0.035198    -0.001315  1.000000 -0.029123
# fc                  0.033334  0.003593    -0.000434 -0.029123  1.000000
#
#                  four_g  int_memory     m_dep  mobile_wt   n_cores        pc  \
# battery_power  0.015665   -0.004004  0.034085   0.001844 -0.029727  0.031441
# blue           0.013443    0.041177  0.004049  -0.008605  0.036161 -0.009952
# clock_speed   -0.043073    0.006545 -0.014364   0.012350 -0.005724 -0.005245
# dual_sim       0.003187   -0.015679 -0.022142  -0.008979 -0.024658 -0.017143
# fc            -0.016560   -0.029133 -0.001791   0.023618 -0.013356  0.644595
#
# ...

# %%
top_features=corr.index
plt.figure(figsize=(20,20))
sns.heatmap(df[top_features].corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
# remove the highly correlated features

# %%
threshold=0.5

# %%
# find and remove the correlated features 
def correlation(dataset,threshold):
    col_corr=set()#set all the names of the correlated columns 
    corr_matrix=dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i,j])>threshold:
                colname=corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
correlation(df.iloc[:,:-1],0.5)
# Out:
# {'pc', 'px_width', 'sc_w', 'three_g'}

# %%
df.drop(columns=['pc', 'px_width', 'sc_w', 'three_g'],axis=1,inplace=True)

# %%
df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  px_height   ram  sc_h  talk_time  \
# ...

# %%
# information Gain
from sklearn.feature_selection import mutual_info_classif
mutual_info=mutual_info_classif(x,y)

# %%
mutual_data=pd.Series(mutual_info,index=x.columns)
mutual_data.sort_values(ascending=False)
# Out:
# ram              0.849732
# px_width         0.030849
# px_height        0.027450
# battery_power    0.024432
# touch_screen     0.020970
# dual_sim         0.016979
# mobile_wt        0.013814
# clock_speed      0.010846
# n_cores          0.010522
# sc_h             0.009806
# four_g           0.008365
# blue             0.008283
# sc_w             0.005732
# talk_time        0.005091
# pc               0.004489
# fc               0.003642
# int_memory       0.003176
# m_dep            0.000000
# three_g          0.000000
# wifi             0.000000
# dtype: float64
